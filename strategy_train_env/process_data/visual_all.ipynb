# %%
import pandas as pd
import seaborn as sns
from scipy.stats import norm
import numpy as np
from sklearn.mixture import GaussianMixture
from fitter import Fitter

data = pd.read_csv("../data/splited_data/period-7_0.csv")
data = data[data["advertiserNumber"]==0]
x = data["pValue"].values
y = data["leastWinningCost"].values

x = x[x> 0]
x = x[x < 0.0015]  # 过滤掉异常值

f = Fitter(x,bins=200,distributions="common")  # 创建Fitter类
f.fit()  # 调用fit函数拟合分布
# Out:
# 2025-06-06 17:12:04.728 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted expon distribution with error=37223518.460942)
# 2025-06-06 17:12:04.742 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted norm distribution with error=67336681.777706)
# 2025-06-06 17:12:04.743 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted uniform distribution with error=91290824.61843)
# 2025-06-06 17:12:04.745 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted rayleigh distribution with error=53374414.386093)
# 2025-06-06 17:12:04.794 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted cauchy distribution with error=21652804.971342)
# 2025-06-06 17:12:04.823 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted powerlaw distribution with error=78605051.255501)
# 2025-06-06 17:12:04.842 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted lognorm distribution with error=12224789.309648)
# 2025-06-06 17:12:05.028 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted gamma distribution with error=20868911.494769)
# 2025-06-06 17:12:05.247 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted chi2 distribution with error=384230582.278575)
# 2025-06-06 17:12:05.756 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted exponpow distribution with error=39721458.095813)

# %%
f.summary()  # 输出拟合结果
# Out:
#           sumsquare_error          aic          bic    kl_div  ks_statistic  \
# lognorm      1.222479e+07 -2348.216780 -2321.908547  0.060487      0.058258
# gamma        2.086891e+07 -2380.304224 -2353.995991  0.076658      0.083853
# cauchy       2.165280e+07 -2123.168687 -2105.629866  0.139012      0.171307
# expon        3.722352e+07 -2390.670458 -2373.131636  0.114018      0.105378
# exponpow     3.972146e+07 -2424.921695 -2398.613462  0.118717      0.124635
#
#               ks_pvalue
# lognorm   1.050915e-140
# gamma     2.862222e-291
# cauchy     0.000000e+00
# expon      0.000000e+00
# exponpow   0.000000e+00
